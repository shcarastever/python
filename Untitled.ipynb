# %%
import sys
import numpy as np

# %%
import pandas as pd

# %%
g7_pop = pd.series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523])

# %%
g7_pop

# %%
g7_pop.values

# %%
print(g7_pop)

# %%
print("hello world")
